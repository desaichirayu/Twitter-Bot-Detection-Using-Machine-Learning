# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")


suser_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_users/spam_users_1.csv");
suser_ds1= suser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()
suser_ds2 = suser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count"]]

suser_ds2_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_users/spam_users_2.csv");
suser_ds2 = suser_ds2_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

suser_ds3_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_users/spam_users_3.csv");
suser_ds3 = suser_ds3_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

guser_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_users/genuine_users.csv");
guser_ds1 = guser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

tuser_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_users/traditional_users_1.csv");
tuser_ds1 = tuser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()


stweet_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_tweets/spam_tweets_1.csv");
# stweet_ds1 = stweet_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()
stweet_data = stweet_ds1_full[["id","user_id","reply_count","retweet_count","num_urls","num_mentions","num_hashtags","favorite_count","possibly_sensitive"]]


stweet_ds2_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_tweets/spam_tweets_2.csv");
# stweet_ds2 = stweet_ds2_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

stweet_ds2_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_tweets/spam_tweets_3.csv");
# stweet_ds2 = stweet_ds2_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

gtweet_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_tweets/genuine_tweets.csv");
# gtweet_ds1 = gtweet_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()

ttweet_ds1_full = pd.read_csv("/Users/ruchitha/Desktop/ML_Project/cresci-2017.csv/datasets_full.csv/all_tweets/traditional_tweets_1.csv");
# ttweet_ds1 = ttweet_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count", "lang", "default_profile", "protected", "verified", "description", "contributors_enabled"]].copy()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
suser_ds2 = suser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count"]]
stweet_data = stweet_ds1_full[["id","user_id","reply_count","retweet_count","num_urls","num_mentions","num_hashtags","favorite_count","possibly_sensitive"]]
guser_ds2 = guser_ds1_full[["id", "name", "screen_name", "statuses_count", "followers_count", "friends_count"]]
gtweet_data = gtweet_ds1_full[["id","user_id","reply_count","retweet_count","num_urls","num_mentions","num_hashtags","favorite_count","possibly_sensitive"]]

# %%
from dateutil import parser
from datetime import datetime
import math

# method to calculate the age of the account given creation time
def calculate_age(creation_date):
    today = datetime.now()
    return today.year - creation_date.year - ((today.month, today.day) < (creation_date.month, creation_date.day))

# checks for nan
def is_nan(x):
    return (x is np.nan or x != x)


# age of the account
account_age = []
# digits in screen name
digits_in_screenname = []
#digits count in name
digit_count_name = []
# tweet length
tweets_length = []
# user name length
user_name_len = []
# screen name length
screen_name_len = []
# name similarity
name_sim = []
# friendship =  friends_count / follower_count
friendship = []
# followship = follower_count / friends_count
followship = []
#Interestingness  = Favourites_count / statuses_count
interestingness = []
#activeness  = status_count/ account_age
activeness = []
#name ratio  = 
name_ratio = []

for i in range(0, suser_ds1_full.shape[0]):
    # conveting string to datetime format
    parsed_datetime = datetime.strptime(suser_ds1_full['created_at'].iloc[i],"%a %b %d %H:%M:%S %z %Y")
    # calculating the age of the account
    accnt_age = calculate_age(parsed_datetime)
    account_age.append(accnt_age)
    # digits in screen name
    digits_in_screenname.append(sum(c.isdigit() for c in suser_ds1_full['screen_name'].iloc[i] ))
    # digits in name
    digit_count_name.append(sum(c.isdigit() for c in suser_ds1_full['name'].iloc[i]))
    # username length
    usr_name_len = len(suser_ds1_full['name'].iloc[i])
    user_name_len.append(usr_name_len)
    # screen name length
    scrn_name_len = len(suser_ds1_full['screen_name'].iloc[i])
    screen_name_len.append(scrn_name_len)
    
    # how interesting is the account
    fav_cnt = suser_ds1_full['favourites_count'].iloc[i]
    status_cnt = suser_ds1_full['statuses_count'].iloc[i]
    if(status_cnt != 0):
        fav_val= math.nan if(is_nan(fav_cnt) or is_nan(status_cnt)) else (fav_cnt/ status_cnt)
        interestingness.append(fav_val)
    else:
        interestingness.append(0)              
    
    # followship score
    follow_cnt = suser_ds1_full['followers_count'].iloc[i] 
    frnd_cnt = suser_ds1_full['friends_count'].iloc[i]
    if(frnd_cnt != 0):
        followship.append(math.nan if(is_nan(follow_cnt) or is_nan(frnd_cnt)) else (follow_cnt/frnd_cnt) )
    else:  
        followship.append(math.nan)
    
    # friendship score
    if(follow_cnt != 0):
        friendship.append( math.nan if(is_nan(follow_cnt) or is_nan(frnd_cnt)) else (frnd_cnt/follow_cnt))
    else:  
        friendship.append(math.nan)
                       
#     # activeness score
#     if(account_age != 0):
#         activeness.append( math.nan if(is_nan(status_cnt) or is_nan(account_age)) else (status_cnt/ account_age))
#     else: 
#         activeness.append(math.nan)
    
    #name ratio
    if(scrn_name_len != 0):
        name_ratio.append(usr_name_len/ scrn_name_len)
    else: 
        name_ratio.append(math.nan)

# %%
# activeness1 = []
# for i in range(0, suser_ds1_full.shape[0]):
#      # activeness score
#     if(account_age != 0):
#         activeness1.append( math.nan if(is_nan(status_cnt) or is_nan(account_age)) else (status_cnt/ account_age))
#     else: 
#         activeness1.append(math.nan)

# %%
# print(type(activeness1[0]))
# age = calculate_age(datetime.strptime(suser_ds1_full['created_at'].iloc[0],"%a %b %d %H:%M:%S %z %Y"))
# print(suser_ds1_full['statuses_count'].iloc[0])
# print(suser_ds1_full['statuses_count'].iloc[0]/age )

# %%
suser_ds2['account_age'] = account_age
suser_ds2['digits_in_screenname'] = digits_in_screenname
suser_ds2['digit_count_name'] = digit_count_name
suser_ds2['user_name_len'] = user_name_len
suser_ds2['screen_name_len'] = screen_name_len
suser_ds2['interestingness'] = interestingness
suser_ds2['friendship'] = friendship
suser_ds2['followship'] = followship
# suser_ds2['activeness'] = activeness
suser_ds2['name_ratio'] = name_ratio
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Features for genuine users
from dateutil import parser
from datetime import datetime
import math

# method to calculate the age of the account given creation time
def calculate_age(creation_date):
    today = datetime.now()
    return today.year - creation_date.year - ((today.month, today.day) < (creation_date.month, creation_date.day))

# checks for nan
def is_nan(x):
    return (x is np.nan or x != x)


# age of the account
g_account_age = []
# digits in screen name
g_digits_in_screenname = []
#digits count in name
g_digit_count_name = []
# tweet length
g_tweets_length = []
# user name length
g_user_name_len = []
# screen name length
g_screen_name_len = []
# name similarity
g_name_sim = []
# friendship =  friends_count / follower_count
g_friendship = []
# followship = follower_count / friends_count
g_followship = []
#Interestingness  = Favourites_count / statuses_count
g_interestingness = []
#activeness  = status_count/ account_age
g_activeness = []
#name ratio  = 
g_name_ratio = []

for i in range(0, guser_ds1_full.shape[0]):
    # conveting string to datetime format
    parsed_datetime = datetime.strptime(guser_ds1_full['created_at'].iloc[i],"%a %b %d %H:%M:%S %z %Y")
    # calculating the age of the account
    accnt_age = calculate_age(parsed_datetime)
    g_account_age.append(accnt_age)
    # digits in screen name
    g_digits_in_screenname.append(sum(c.isdigit() for c in str(guser_ds1_full['screen_name'].iloc[i])))
    # digits in name
    g_digit_count_name.append(sum(c.isdigit() for c in str(guser_ds1_full['name'].iloc[i])))
    # username length
    usr_name_len = len(str(guser_ds1_full['name'].iloc[i]))
    g_user_name_len.append(usr_name_len)
    # screen name length
    scrn_name_len = len(str(guser_ds1_full['screen_name'].iloc[i]))
    g_screen_name_len.append(scrn_name_len)
    
    # how interesting is the account
    fav_cnt = guser_ds1_full['favourites_count'].iloc[i]
    status_cnt = guser_ds1_full['statuses_count'].iloc[i]
    if(status_cnt != 0):
        fav_val= math.nan if(is_nan(fav_cnt) or is_nan(status_cnt)) else (fav_cnt/ status_cnt)
        g_interestingness.append(fav_val)
    else:
        g_interestingness.append(0)              
    
    # followship score
    follow_cnt = guser_ds1_full['followers_count'].iloc[i] 
    frnd_cnt = guser_ds1_full['friends_count'].iloc[i]
    if(frnd_cnt != 0):
        g_followship.append(math.nan if(is_nan(follow_cnt) or is_nan(frnd_cnt)) else (follow_cnt/frnd_cnt) )
    else:  
        g_followship.append(math.nan)
    
    # friendship score
    if(follow_cnt != 0):
        g_friendship.append( math.nan if(is_nan(follow_cnt) or is_nan(frnd_cnt)) else (frnd_cnt/follow_cnt))
    else:  
        g_friendship.append(math.nan)
                       
#     # activeness score
#     if(account_age != 0):
#         activeness.append( math.nan if(is_nan(status_cnt) or is_nan(account_age)) else (status_cnt/ account_age))
#     else: 
#         activeness.append(math.nan)
    
    #name ratio
    if(scrn_name_len != 0):
        g_name_ratio.append(usr_name_len/ scrn_name_len)
    else: 
        g_name_ratio.append(math.nan)

# %%
guser_ds2['account_age'] = g_account_age
guser_ds2['digits_in_screenname'] = g_digits_in_screenname
guser_ds2['digit_count_name'] = g_digit_count_name
guser_ds2['user_name_len'] = g_user_name_len
guser_ds2['screen_name_len'] = g_screen_name_len
guser_ds2['interestingness'] = g_interestingness
guser_ds2['friendship'] = g_friendship
guser_ds2['followship'] = g_followship
# gsuser_ds2['activeness'] = g_activeness
guser_ds2['name_ratio'] = g_name_ratio
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# both tweet and usercombined features
# tweet length
# uri_ratio -> characters in url/ tweet_length
# mention_ratio -> characters in user mention / tweet_length

tweet_length = []
for j in  range(0,len(stweet_ds1_full)):
    # tweet length 
    tweet_length.append(len(str(stweet_ds1_full['text'].iloc[j])))

stweet_data['tweet_length'] =  tweet_length
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# both tweet and usercombined features
# tweet length
# uri_ratio -> characters in url/ tweet_length
# mention_ratio -> characters in user mention / tweet_length

gtweet_length = []
for j in  range(0,len(gtweet_ds1_full)):
    # tweet length 
    gtweet_length.append(len(str(gtweet_ds1_full['text'].iloc[j])))

gtweet_data['tweet_length'] =  gtweet_length
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# gen_label = pd.DataFrame([0] * len(guser_ds2))
# scam_label = pd.DataFrame([1] * len(suser_ds2))
guser_ds2['label'] = 0
suser_ds2['label'] = 1

frame1 = [guser_ds2, suser_ds2]
dataset = pd.concat(frame1)

frame3 = [gtweet_data, stweet_data ]
tweet_dataset = pd.concat(frame3)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
dataset.columns

# %%
stweet_data.columns
gtweet_data['user_id']

# %%
dataset.rename(columns ={'id': 'user_id'}, inplace =True)
tweet_user_dataset = pd.merge( tweet_dataset, dataset,  how='outer', on = ['user_id'] )

# %%
data_set_no_label = tweet_user_dataset
data_set_no_label = tweet_user_dataset.loc[:, data_set_no_label.columns != 'name']
data_set_no_label = data_set_no_label.loc[:, data_set_no_label.columns != 'screen_name']
#data_set_no_label = data_set_no_label.groupby(data_set_no_label.columns, axis = 1).transform(lambda x: x.fillna(x.mean()))
data_set_no_label.fillna(data_set_no_label.mean())
data_set_no_label.loc[:, data_set_no_label.columns != 'id']
# Out:
#               user_id  reply_count  retweet_count  num_urls  num_mentions  \
# 0        6.780330e+05          0.0            1.0       0.0           1.0
# 1        6.780330e+05          0.0            0.0       0.0           0.0
# 2        6.780330e+05          0.0            0.0       0.0           0.0
# 3        6.780330e+05          0.0            2.0       0.0           0.0
# 4        6.780330e+05          0.0            0.0       0.0           0.0
# 5        6.780330e+05          0.0            0.0       1.0           0.0
# 6        6.780330e+05          0.0            1.0       1.0           1.0
# 7        6.780330e+05          0.0           49.0       0.0           1.0
# 8        6.780330e+05          0.0          231.0       1.0           3.0
# 9        6.780330e+05          0.0            0.0       0.0           2.0
# 10       6.780330e+05          0.0           11.0       1.0           1.0
# 11       6.780330e+05          0.0            0.0       0.0           1.0
# ...

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# X = data_set_no_label.as_matrix().astype(np.float)
# y = label.as_matrix().astype(np.float)

data_set_no_label = clean_dataset(data_set_no_label)
label = data_set_no_label['label']
data_set_no_label = data_set_no_label.loc[:, data_set_no_label.columns != 'label']
x_train, x_test, y_train, y_test = train_test_split(data_set_no_label, label, test_size=0.33, random_state=42)

# %%
x_train
# Out:
#                    id       user_id  reply_count  retweet_count  num_urls  \
# 2492859  4.685530e+17  2.285992e+08          0.0          143.0       1.0
# 1074604  4.944037e+17  5.355371e+08          0.0           96.0       1.0
# 1430285  5.312176e+17  1.827304e+07          0.0          145.0       0.0
# 1311157  5.620560e+17  5.447582e+08          0.0         1719.0       1.0
# 1128236  4.738718e+17  1.712718e+07          0.0            0.0       1.0
# 2492485  5.008567e+17  2.285992e+08          0.0            0.0       1.0
# 2845362  5.183530e+17  3.977343e+07          0.0            0.0       1.0
# 1128844  4.506177e+17  1.712718e+07          0.0            0.0       1.0
# 65144    5.830377e+17  1.494211e+08          0.0         1157.0       0.0
# 2348299  5.627485e+17  2.226178e+08          0.0           14.0       0.0
# 4448631  5.001636e+17  2.525273e+09          0.0            0.0       1.0
# 989209   4.204959e+17  5.312123e+08          0.0            0.0       1.0
# ...

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.7444726810673443

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('Recall:', recall_score(y_test, predictions,average="micro")*100,"%")
print('Precision:', precision_score(y_test, predictions,average="micro")*100,"%")

# %%
from sklearn import svm
import math
clf = svm.SVC(gamma=0.01)
clf.fit(x_train, y_train) 
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
predictions = clf.predict(x_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions) 
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 0.5054971008152823

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('Recall:', recall_score(y_test, predictions,average="micro")*100,"%")
print('Precision:', precision_score(y_test, predictions,average="micro")*100,"%")

# %%
from sklearn import svm
import math
clf = svm.SVC(gamma=0.1)
clf.fit(x_train, y_train) 
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
predictions = clf.predict(x_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions) 
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 0.5054971008152823

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('Recall:', recall_score(y_test, predictions,average="micro")*100,"%")
print('Precision:', precision_score(y_test, predictions,average="micro")*100,"%")

# %%
x_train.head()
# Out:
#                    id      user_id  reply_count  retweet_count  num_urls  \
# 2492859  4.685530e+17  228599159.0          0.0          143.0       1.0
# 1074604  4.944037e+17  535537105.0          0.0           96.0       1.0
# 1430285  5.312176e+17   18273041.0          0.0          145.0       0.0
# 1311157  5.620560e+17  544758247.0          0.0         1719.0       1.0
# 1128236  4.738718e+17   17127177.0          0.0            0.0       1.0
#
#          num_mentions  num_hashtags  favorite_count  possibly_sensitive  \
# 2492859           1.0           0.0             0.0                 1.0
# 1074604           1.0           0.0             0.0                 1.0
# 1430285           1.0           1.0             0.0                 1.0
# 1311157           1.0           2.0             0.0                 1.0
# 1128236           0.0           0.0             0.0                 1.0
#
#          tweet_length     ...      friends_count  account_age  \
# ...

# %%
x_train.columns
# Out:
# Index(['id', 'user_id', 'reply_count', 'retweet_count', 'num_urls',
#        'num_mentions', 'num_hashtags', 'favorite_count', 'possibly_sensitive',
#        'tweet_length', 'statuses_count', 'followers_count', 'friends_count',
#        'account_age', 'digits_in_screenname', 'digit_count_name',
#        'user_name_len', 'screen_name_len', 'interestingness', 'friendship',
#        'followship', 'name_ratio'],
#       dtype='object')

# %%
data_set_no_label_1 = data_set_no_label
data_set_no_label_1 = data_set_no_label_1.drop(columns = ['reply_count','retweet_count','reply_count','favorite_count','digits_in_screenname','digit_count_name','id','user_id'])
x_train, x_test, y_train, y_test = train_test_split(data_set_no_label_1, label, test_size=0.33, random_state=42)
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.8861499364675984

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('Recall:', recall_score(y_test, predictions,average="micro")*100,"%")
print('Precision:', precision_score(y_test, predictions,average="micro")*100,"%")

# %%
x_train.columns
# Out:
# Index(['num_urls', 'num_mentions', 'num_hashtags', 'possibly_sensitive',
#        'tweet_length', 'statuses_count', 'followers_count', 'friends_count',
#        'account_age', 'user_name_len', 'screen_name_len', 'interestingness',
#        'friendship', 'followship', 'name_ratio'],
#       dtype='object')

# %%
from sklearn import svm
import math
clf = svm.SVC(gamma=0.01)
clf.fit(x_train, y_train) 
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
predictions = clf.predict(x_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions) 
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 0.0

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('Recall:', recall_score(y_test, predictions,average="micro")*100,"%")
print('Precision:', precision_score(y_test, predictions,average="micro")*100,"%")
